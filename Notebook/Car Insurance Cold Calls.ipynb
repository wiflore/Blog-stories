# %% [markdown]
# https://www.kaggle.com/kondla/carinsurance/downloads/carInsurance_test.csv/1
#
# https://storage.googleapis.com/kaggle-datasets/1411/2534/DSS_DMC_Description.pdf

# %%
import pandas as pd

# %%
df_call_center_train = pd.read_csv("https://raw.githubusercontent.com/wiflorez/Blog-stories/master/data/carInsurance_train.csv")
df_call_center_test = pd.read_csv("https://raw.githubusercontent.com/wiflorez/Blog-stories/master/data/carInsurance_test.csv")

# %%
df_call_center_train.head()
# Out:
#    Id  Age          Job  Marital Education  Default  Balance  HHInsurance  \
# 0   1   32   management   single  tertiary        0     1218            1
# 1   2   32  blue-collar  married   primary        0     1156            1
# 2   3   29   management   single  tertiary        0      637            1
# 3   4   25      student   single   primary        0      373            1
# 4   5   30   management  married  tertiary        0     2694            0
#
#    CarLoan Communication  LastContactDay LastContactMonth  NoOfContacts  \
# 0        0     telephone              28              jan             2
# 1        0           NaN              26              may             5
# 2        0      cellular               3              jun             1
# 3        0      cellular              11              may             2
# 4        0      cellular               3              jun             1
#
#    DaysPassed  PrevAttempts  Outcome CallStart   CallEnd  CarInsurance
# ...

# %%
df_call_center_train.describe()
# Out:
#                 Id          Age      Default       Balance  HHInsurance  \
# count  4000.000000  4000.000000  4000.000000   4000.000000   4000.00000
# mean   2000.500000    41.214750     0.014500   1532.937250      0.49275
# std    1154.844867    11.550194     0.119555   3511.452489      0.50001
# min       1.000000    18.000000     0.000000  -3058.000000      0.00000
# 25%    1000.750000    32.000000     0.000000    111.000000      0.00000
# 50%    2000.500000    39.000000     0.000000    551.500000      0.00000
# 75%    3000.250000    49.000000     0.000000   1619.000000      1.00000
# max    4000.000000    95.000000     1.000000  98417.000000      1.00000
#
#            CarLoan  LastContactDay  NoOfContacts   DaysPassed  PrevAttempts  \
# count  4000.000000     4000.000000   4000.000000  4000.000000   4000.000000
# mean      0.133000       15.721250      2.607250    48.706500      0.717500
# std       0.339617        8.425307      3.064204   106.685385      2.078647
# ...

# %%
"""import pycodestyle
style_checker = pycodestyle.StyleGuide()
result = style_checker.check_files(["nay_pep8.py", "yay_pep8.py"])

# Print result of PEP 8 style check
print(result.messages)
"""
# Out:
# 'import pycodestyle\nstyle_checker = pycodestyle.StyleGuide()\nresult = style_checker.check_files(["nay_pep8.py", "yay_pep8.py"])\n\n# Print result of PEP 8 style check\nprint(result.messages)\n'

# %%
import sys
sys.version
# Out:
# '2.7.16 |Anaconda, Inc.| (default, Mar 14 2019, 16:24:02) \n[GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]'

# %% [markdown]
# Business Understanding
# Data Understanding
# Prepare Data
# Model Data
# Results
# Deploy
#
# https://docs.microsoft.com/es-es/azure/machine-learning/team-data-science-process/overview
#
# https://cloud.google.com/ml-engine/docs/tensorflow/ml-solutions-overview
#
# https://docs.microsoft.com/en-gb/azure/machine-learning/team-data-science-process/lifecycle#next-steps
#
# **Data Analysis Process**
#
# **Extract** - Obtain the data from a spreadsheet, SQL, the web, etc.
# **Clean** - Here we could use exploratory visuals.
# **Explore** - Here we use exploratory visuals.
# **Analyze** - Here we might use either exploratory or explanatory visuals.

# %% [markdown]
# **Visualization**
# Identifyint data types
# Data Ink Ratio
# Color
# Shape, size .

# %% [markdown]
# **Univariate**
# Tidy Data
# Bar Charts
# Absolute vs Relative Frequency
# Counting Missing Data
# Pie Charts
# Histograms
# Subplots
# Descriptive Stats, Outliers
# Scales and Tranformations
# Kernel Density Estimation
# Waffle Plots

# %% [markdown]
# **Bivariate**
# Scatterplots and Correlations
# Overplotting, Transparency and Jitter
# Heat Maps
# Violing Plots
# Box Plots
# Clustered Bar
# Categorical Plot
# Faceting
# Adaptation of Univariate
# Line Plots
# Q-Q Plots
# Swarm plots
# Rug and Strip Plots
# Stacked Plots
# Ridgeline Plots

# %% [markdown]
# **Mutivariate**
# Non-Positional Encodings shape, size, color
# Color Palettes
# Faceing in two Directions
# Plot Matrices correlation
# Feactures Engineering
